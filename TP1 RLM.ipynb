# %% [markdown]
# # ex1

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_excel("data.xlsx")
df
# Out:
#     taille_en_pieds_carre  nb_chambres    prix
# 0                    2104            3  399900
# 1                    1600            3  329900
# 2                    2400            3  369000
# 3                    1416            2  232000
# 4                    3000            4  539900
# 5                    1985            4  299900
# 6                    1534            3  314900
# 7                    1427            3  198999
# 8                    1380            3  212000
# 9                    1494            3  242500
# 10                   1940            4  239999
# 11                   2000            3  347000
# 12                   1890            3  329999
# 13                   4478            5  699900
# 14                   1268            3  259900
# 15                   2300            4  449900
# 16                   1320            2  299900
# 17                   1236            3  199900
# 18                   2609            4  499998
# ...

# %%
df.head(5)
# Out:
#    taille_en_pieds_carre  nb_chambres    prix
# 0                   2104            3  399900
# 1                   1600            3  329900
# 2                   2400            3  369000
# 3                   1416            2  232000
# 4                   3000            4  539900

# %%
X=df.iloc[:,:2]

# %%
Y=df.iloc[:,-1]
Y
# Out:
# 0     399900
# 1     329900
# 2     369000
# 3     232000
# 4     539900
# 5     299900
# 6     314900
# 7     198999
# 8     212000
# 9     242500
# 10    239999
# 11    347000
# 12    329999
# 13    699900
# 14    259900
# 15    449900
# 16    299900
# 17    199900
# 18    499998
# 19    599000
# 20    252900
# 21    255000
# 22    242900
# 23    259900
# 24    573900
# 25    249900
# 26    464500
# 27    469000
# 28    475000
# 29    299900
# 30    349900
# 31    169900
# 32    314900
# 33    579900
# 34    285900
# 35    249900
# 36    229900
# 37    345000
# 38    549000
# 39    287000
# 40    368500
# 41    329900
# 42    314000
# 43    299000
# 44    179900
# 45    299900
# 46    239500
# Name: prix, dtype: int64

# %%
X
# Out:
#     taille_en_pieds_carre  nb_chambres
# 0                    2104            3
# 1                    1600            3
# 2                    2400            3
# 3                    1416            2
# 4                    3000            4
# 5                    1985            4
# 6                    1534            3
# 7                    1427            3
# 8                    1380            3
# 9                    1494            3
# 10                   1940            4
# 11                   2000            3
# 12                   1890            3
# 13                   4478            5
# 14                   1268            3
# 15                   2300            4
# 16                   1320            2
# 17                   1236            3
# 18                   2609            4
# 19                   3031            4
# 20                   1767            3
# 21                   1888            2
# 22                   1604            3
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = df.taille_en_pieds_carre
y = df.	nb_chambres
z = df.prix
# make x & y match the shape of z
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x,y,z,c='r', marker='o')

ax.set_xlabel('Feature X')
ax.set_ylabel('Feature Y')
ax.set_zlabel('Target Z')

plt.show()

# %%
x_train , x_test, y_train , y_test = train_test_split(X, Y, random_state=0, test_size= 1/3)

# %%
reg=LinearRegression()

# %%
reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([369647.33504459, 500087.73659911, 328130.30083656, 472277.85514636,
#        417846.48160547, 341805.20024107, 411999.63329673, 220070.5644481 ,
#        286677.77333009, 324714.54068768, 415030.01477434, 338635.60808944,
#        430482.39959029, 230436.66102696, 397489.46984812, 312464.00137413])

# %%
#g=plt.figure()
#g.add_

# %%
lst=np.array([450,5])
lst
# Out:
# array([450,   5])

# %%
y__pred_test=reg.predict([lst])
y__pred_test
# Out:
# F:\Nouveau dossier\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([108552.61728909])

# %% [markdown]
# # ex2

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head(20)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print("le nombre de colonnes est :",len(df.axes[1]))
print("================")
print("le nombre de lignes est:",len(df.axes[0]))
# Out:
# le nombre de colonnes est : 9
# ...
# le nombre de lignes est: 301

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
print(df[['Fuel_Type','Seller_Type','Transmission']].value_counts())
# Out:
# Fuel_Type  Seller_Type  Transmission
# Petrol     Dealer       Manual          116
#            Individual   Manual           95
# Diesel     Dealer       Manual           48
# Petrol     Dealer       Automatic        18
# Diesel     Dealer       Automatic        11
# Petrol     Individual   Automatic        10
# CNG        Dealer       Manual            2
# Diesel     Individual   Automatic         1
# dtype: int64

# %%
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df['Transmission']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 296    0
# 297    0
# 298    0
# 299    0
# 300    0
# Name: Transmission, Length: 301, dtype: int64

# %%
df.replace({'Seller_Type':{'Dealer':0,'Individual':1}},inplace=True)

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner
# 0              0             0      0
# ...

# %%
#df['Seller_Type'].astype('category')

# %%
import seaborn as sns
sns.distplot(df['Present_Price'],kde=True)
# Out:
# F:\Nouveau dossier\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Present_Price', ylabel='Density'>

# %%
# commenter

# %%
sns.boxplot(data=df, x="Fuel_Type", y="Present_Price")
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Present_Price'>

# %%
#commenter

# %%
sns.boxplot(data=df, x="Transmission", y="Present_Price")
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Present_Price'>

# %%
plt.scatter(df['Kms_Driven'],df['Present_Price'])

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,cmap="Blues")
plt.title('Data correlation',size=15)
plt.ylabel('columns',size=15)
plt.xlabel('columns',size=15)
plt.show()

# %%
dupli=df.duplicated()

# %%
dupli.sum()
# Out:
# 2

# %%
X=df[['Year','Selling_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
X
# Out:
#      Year  Selling_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           3.35       27000          0            0             0
# 1    2013           4.75       43000          1            0             0
# 2    2017           7.25        6900          0            0             0
# 3    2011           2.85        5200          0            0             0
# 4    2014           4.60       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016           9.50       33988          1            0             0
# 297  2015           4.00       60000          0            0             0
# 298  2009           3.35       87934          0            0             0
# 299  2017          11.50        9000          1            0             0
# 300  2016           5.30        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
Y=df['Present_Price']
Y
# Out:
# 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: Present_Price, Length: 301, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y, test_size=0.2)

# %%
reg=LinearRegression()

# %%
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
predictions=reg.predict(x_test)

# %%
from sklearn import metrics
metrics.r2_score(y_test,predictions)
# Out:
# 0.872903152028749

# %%
from sklearn.preprocessing import StandardScaler
n_scaler = StandardScaler()
x_train = n_scaler.fit_transform(x_train)
x_test = n_scaler.fit_transform(x_test)

# %%
predictions2=reg.predict(x_test)
predictions2
# Out:
# F:\Nouveau dossier\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1404.32588192, 1405.95928479, 1408.17592294, 1403.33201241,
#        1405.49728188, 1406.19165539, 1407.50817991, 1404.09895003,
#        1405.10819856, 1405.70298712, 1403.79991495, 1408.19178572,
#        1406.72183332, 1403.37930714, 1406.48117239, 1403.77791993,
#        1406.65954955, 1405.5495678 , 1406.54498785, 1405.50227491,
#        1404.07865461, 1406.13437479, 1406.21162559, 1403.74185397,
#        1404.92416974, 1404.62486705, 1405.35704639, 1403.13163507,
#        1406.77148433, 1405.58187619, 1404.06420561, 1404.15624092,
#        1405.28737156, 1405.93184789, 1403.12085539, 1402.49168879,
#        1403.35276851, 1403.30548154, 1404.21966703, 1403.5526966 ,
#        1417.38025457, 1404.05167682, 1406.05476818, 1406.49536423,
# ...

# %%
from sklearn import metrics
metrics.r2_score(y_test,predictions)
# Out:
# 0.872903152028749

# %%
reg.score(x_test,y_test)
# Out:
# F:\Nouveau dossier\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -31391.60564080209

# %%
reg.score(x_train,y_train)
# Out:
# F:\Nouveau dossier\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -25251.754363161977

# %%
mean_squared_error(y_test,predictions)
# Out:
# 7.899897243502453
